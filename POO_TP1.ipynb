# %%
# We start by importing Pandas in order to import the data
import pandas as pd
# The following instruction allows us to read the CSV file and create a DataFrame from it using Pandas
df=pd.read_csv(R'C:/Users/hp/OneDrive/Bureau/tp/titanic-passengers.csv', sep=';')
# Display the CSV file's content
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Display the Dataframe's first five rows
df.head()
# Out:
#    PassengerId Survived  Pclass                                         Name  \
# 0          343       No       2                   Collander, Mr. Erik Gustaf
# 1           76       No       3                      Moen, Mr. Sigurd Hansen
# 2          641       No       3                       Jensen, Mr. Hans Peder
# 3          568       No       3  Palsson, Mrs. Nils (Alma Cornelia Berglund)
# 4          672       No       1                       Davidson, Mr. Thornton
#
#       Sex   Age  SibSp  Parch      Ticket     Fare  Cabin Embarked
# 0    male  28.0      0      0      248740  13.0000    NaN        S
# 1    male  25.0      0      0      348123   7.6500  F G73        S
# 2    male  20.0      0      0      350050   7.8542    NaN        S
# 3  female  29.0      0      4      349909  21.0750    NaN        S
# 4    male  31.0      1      0  F.C. 12750  52.0000    B71        S

# %%
# Display general informations regarding the columns and data values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    object
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 83.7+ KB

# %%
# Finding the missing values NaN in all the columns of the Dataframe
df.isnull().sum()
# Through the results, we can see that the columns containing NaNs are Age, Cabin and Embarked
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Counting the total number of elements contained in the column Cabin
number_of_elements=len(df['Cabin'])
print('number of elements',number_of_elements)
# Out:
# number of elements 891

# %%
# Display each value's count to determine the most frequent value
print(df['Cabin'].value_counts())
# Out:
# Cabin
# G6             4
# B96 B98        4
# C23 C25 C27    4
# F33            3
# D              3
#               ..
# C91            1
# D45            1
# F G63          1
# A34            1
# E63            1
# Name: count, Length: 147, dtype: int64

# %%
# Replace the NaNs with the most frequent value and display, while saving the changes made
df['Cabin'].fillna('G6',inplace=True)

# %%
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Display the Dataframe's last five rows
df.tail()
# Out:
#      PassengerId Survived  Pclass  \
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 886                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 887                              Sirayanian, Mr. Orsen    male  22.0      0
# 888                                Cacic, Miss. Marija  female  30.0      0
# 889                   Petroff, Mr. Pastcho ("Pentcho")    male   NaN      0
# 890  Phillips, Miss. Kate Florence ("Mrs Kate Louis...  female  19.0      0
#
#      Parch  Ticket     Fare Cabin Embarked
# 886      0  237736  30.0708    G6        C
# 887      0    2669   7.2292    G6        C
# 888      0  315084   8.6625    G6        S
# 889      0  349215   7.8958    G6        S
# 890      0  250655  26.0000    G6        S

# %%
# Reexecuting the following instruction to check if the missing values present in Cabin has been replaced
df.isnull().sum()
# The results show no missing values in the column Cabin
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin            0
# Embarked         2
# dtype: int64

# %%
# Replacing the missing values in the column Age by the average of the non-zero values
df['Age'].fillna(df['Age'].mean(),inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Reexecuting the following instruction to check if the missing values present in Age has been replaced
df.isnull().sum()
# The results show no missing values in the column Age
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       2
# dtype: int64

# %%
# Import the LabelEncoder function from the sklearn library
from sklearn.preprocessing import LabelEncoder
encoder=LabelEncoder()
# Replace the categorical values present in the column Embarked with numerical using the LabelEncoder function
df['Embarked']=encoder.fit_transform(df['Embarked'])
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Replacing the missing values in the column Embarked by the median of the non-zero values
df['Embarked'].fillna(df['Embarked'].median(),inplace=True)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Reexecuting the following instruction to check if the missing values present in Embarked has been replaced
df.isnull().sum()
# The results show no missing values in the column Embarked
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
df.isnull()
# The output for all the columns is 'False' which means that no missing values has been  detected in any of them
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False  False  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
# Import the data visualisation libraries
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Generating a Histogram to visualise the data contained in the column Age of the Dataframe by calling Matplotlib library
plt.title('Histogram of different ages')
plt.xlabel('Age')
# Display the Histogram of different ages
df['Age'].plot.hist()
# As a brief interpretation, we can say that the age range of the passengers is between 0 and 80, and the most frequent age range is between 20 and 30
# Out:
# <Axes: title={'center': 'Histogram of different ages'}, ylabel='Frequency'>

# %%
# Generating a Barplot to visualise the categorical data contained in the column Sex of the Dataframe by calling Seaborn library
# Display the Barplot of different sex categories using the 'countplot' function
sns.countplot(x='Sex',data=df)
plt.xticks(rotation=-90)
# As a brief interpretation, we can say that there were more Male passengers than Female on board
# Out:
# (array([0, 1]), [Text(0, 0, 'male'), Text(1, 0, 'female')])

# %%
# Visualisation of the correlation between a numerical and a categorical feature to assess the impact of the 'Age' and 'Sex' parameters on passengers survival in a Histogram
g=sns.FacetGrid(df,col="Sex")
g.map(plt.hist,'Age',bins=20)
# The results show that most of the survivers are Male aged between 20 and 40. As for the Female survivers, they are aged between 20 and 40 aswell
# Out:
# C:\Users\hp\anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
# Computing the correlation between the numerical values of the DataFrame using the plot_correlation_map function
def plot_correlation_map(df): 
 # Select the numerical columns only 
   numeric_columns = df.select_dtypes(include=['number']) 
   # Calcul of the correlation matrix for the numerical columns
   corr = numeric_columns.corr()
   # Specify the figure's size
   plt.figure(figsize=(12, 10)) 
   # Choose the color palette 
   cmap = sns.diverging_palette(220, 10, as_cmap=True) 
   # Trace a HeatMap that allows us to visualise the correlation between different values of the DtaFrame
   sns.heatmap(corr, cmap=cmap, square=True, cbar_kws={'shrink': 0.9}, annot=True, annot_kws={'fontsize': 12}) 
# Display the HeatMap 
plot_correlation_map(df)

# %%
# The 'plot_correlation_map()' function aims to create a visual representation of the correlation between variables,in order to evaluate how they are related to each other and it can help identify which pairs of variables tend to move together
# The intensity of the color indicates the strength of the correlation
# A good positif correllation equals a strong correlation coefficient (close to 1), and means that two values increase in a linear manner ; as one variable increases, the other tends to increase as well
# A good negative correlation equals a correlation coefficient that's close to -1, which reflects a linear but opposite relationship where as one variable increases, the other tends to decrease
# According to the heatmap and the previous statements, the best correlation are the ones between the columns :
# Parch and Fare
# Parch and SibSp
# Parch and Age
# Pclass and Fare
# Pclass and Age

# %%
# Delete the column 'Name' using the function Drop
# The 'Axis' parameter is set to 1 because we aim to delete a column
# If we wanted to delete a row, we would have set axis=0
df.drop('Name',axis=1)
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Creating a new column named 'Title' to assign the appropriate title for each passenger using the column 'Name'

import pandas as pd
df=pd.read_csv(R'C:/Users/hp/OneDrive/Bureau/tp/titanic-passengers.csv', sep=';')

# Define the Title Dictionary

Title_Dictionary = {
    "Capt": "Officer",
    "Col": "Officer",
    "Major": "Officer",
    "Dr": "Officer",
    "Rev": "Officer",
    "Jonkheer": "Royalty",
    "Don": "Royalty",
    "Sir": "Royalty",
    "Lady": "Royalty",
    "the Countess": "Royalty",
    "Dona": "Royalty",
    "Mme": "Miss",
    "Mlle": "Miss",
    "Miss": "Miss",
    "Ms": "Mrs",
    "Mr": "Mrs",
    "Mrs": "Mrs",
    "Master": "Master"
}

# Use the function 'apply' to apply a function to each element of the column
# The 'lambda' function extracts the title from the name in the expected format and uses the `Title_Dictionary' dictionary to assign the appropriate title
# If the title is not found in the dictionary, "Unknown" is set as a default value

df['Title'] = df['Name'].apply(lambda x: Title_Dictionary.get(x.split(",")[1].split(".")[0].strip(), "Unknown"))

# Display the DataFrame with the new column "Title"
df
# Out:
#      PassengerId Survived  Pclass  \
# 0            343       No       2
# 1             76       No       3
# 2            641       No       3
# 3            568       No       3
# 4            672       No       1
# ..           ...      ...     ...
# 886           10      Yes       2
# 887           61       No       3
# 888          535       No       3
# 889          102       No       3
# 890          428      Yes       2
#
#                                                   Name     Sex   Age  SibSp  \
# 0                           Collander, Mr. Erik Gustaf    male  28.0      0
# 1                              Moen, Mr. Sigurd Hansen    male  25.0      0
# 2                               Jensen, Mr. Hans Peder    male  20.0      0
# 3          Palsson, Mrs. Nils (Alma Cornelia Berglund)  female  29.0      0
# 4                               Davidson, Mr. Thornton    male  31.0      1
# ..                                                 ...     ...   ...    ...
# ...
